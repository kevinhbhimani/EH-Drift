# %%
import numpy as np
import matplotlib.pyplot as plt
from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>")) #makes the notebook wider
plt.style.use('default')
# Out:
# <style>.container { width:100% !important; }</style>

# %%
n_iter = 4000
time_step_calc = 0.2
step_time_out = 10
time = np.linspace(start=0, stop= int (n_iter*time_step_calc - step_time_out*time_step_calc ), num= (int) (n_iter/step_time_out))

# %%
#dat_10_kev_20u = np.loadtxt('/Users/kevinhbhimani/Desktop/GPU_work/siggen_ccd/waveforms/10.00_keV/grid_0.0200/self_repulsion_1/P42575A/q=0.00/signal_r=15.00_phi=0.00_z=0.05.txt')
dat_100_kev_20u = np.loadtxt('/Users/kevinhbhimani/Desktop/GPU_work/siggen_ccd/waveforms/100.00_keV/grid_0.0200/self_repulsion_1/P42575A/q=0.00/signal_r=15.00_phi=0.00_z=5.05.txt')
#dat_800_kev_20u = np.loadtxt('/Users/kevinhbhimani/Desktop/GPU_work/siggen_ccd/waveforms/800.00_keV/grid_0.0200/self_repulsion_1/P42575A/q=0.00/signal_r=15.00_phi=0.00_z=0.05.txt')

# %%
#dat_10_kev_10u = np.loadtxt('/Users/kevinhbhimani/Desktop/GPU_work/siggen_ccd/waveforms/10.00_keV/grid_0.0100/self_repulsion_1/P42575A/q=0.00/signal_r=15.00_phi=0.00_z=0.05.txt')
dat_100_kev_10u = np.loadtxt('/Users/kevinhbhimani/Desktop/GPU_work/siggen_ccd/waveforms/100.00_keV/grid_0.0100/self_repulsion_1/P42575A/q=0.00/signal_r=15.00_phi=0.00_z=5.05.txt')
#dat_800_kev_10u = np.loadtxt('/Users/kevinhbhimani/Desktop/GPU_work/siggen_ccd/waveforms/800.00_keV/grid_0.0100/self_repulsion_1/P42575A/q=0.00/signal_r=15.00_phi=0.00_z=0.05.txt')

# %%
plt.plot(np.arange(0,800,0.20),dat_100_kev_10u,'-',markersize=2,color='tab:red')
plt.plot(np.arange(0,800,0.20), dat_100_kev_20u,'-',markersize=2,color='tab:blue')

plt.legend(['10 $\mu$ grid', '20 $\mu$ grid'])

plt.xlabel('Time (ns)')
plt.ylabel('Fraction of charge carriers collected')
plt.title('Signal collected at $r=15,z=5.05$, Energy=$100$keV')
# Out:
# Text(0.5, 1.0, 'Signal collected at $r=15,z=5.05$, Energy=$100$keV')
