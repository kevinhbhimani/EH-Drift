# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from io import StringIO


from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>")) #makes the notebook wider
plt.style.use('default')
# %matplotlib inline 
#makes plots fit the page

#plt.style.use('seaborn-deep')
# Out:
# /var/folders/kf/hx5km7bs4hg_5ytlj6pnz_100000gn/T/ipykernel_70142/148466520.py:8: DeprecationWarning: Importing display from IPython.core.display is deprecated since IPython 7.14, please import from IPython display
#   from IPython.core.display import display, HTML
# <style>.container { width:100% !important; }</style>

# %%
sim_time=6000
time_step_calc = 0.05
n_iter = sim_time/time_step_calc
step_time_out = 1 #out every step for now
time = np.linspace(start=0, stop= n_iter*time_step_calc - step_time_out*time_step_calc, num= (int) (sim_time/time_step_calc))

# %%
print(len(time))
# Out:
# 120000

# %%
c_10m=np.loadtxt('/Users/kevinhbhimani/Desktop/siggen_ccd/courant_numbers/courant_numb_grid=0.0100_ts_0.0500.txt')
c_15m=np.loadtxt('/Users/kevinhbhimani/Desktop/siggen_ccd/courant_numbers/courant_numb_grid=0.0150_ts_0.0500.txt')
c_20m=np.loadtxt('/Users/kevinhbhimani/Desktop/siggen_ccd/courant_numbers/courant_numb_grid=0.0200_ts_0.0500.txt')
c_30m=np.loadtxt('/Users/kevinhbhimani/Desktop/siggen_ccd/courant_numbers/courant_numb_grid=0.0250_ts_0.0500.txt')
c_40m=np.loadtxt('/Users/kevinhbhimani/Desktop/siggen_ccd/courant_numbers/courant_numb_grid=0.0300_ts_0.0500.txt')
c_50m=np.loadtxt('/Users/kevinhbhimani/Desktop/siggen_ccd/courant_numbers/courant_numb_grid=0.0400_ts_0.0500.txt')

# %%
cut = time<4000
plt.plot(time[cut],c_10m[cut]*0.01,'o',markersize=2,color='tab:red')
plt.plot(time[cut],c_20m[cut]*0.02,'o',markersize=2,color='tab:orange')
plt.plot(time[cut],c_30m[cut]*0.03,'o',markersize=2,color='tab:purple')
plt.plot(time[cut],c_40m[cut]*0.04,'o',markersize=2,color='tab:green')
plt.plot(time[cut],c_50m[cut]*0.05,'o',markersize=2,color='tab:blue')

plt.legend(['10 micron','20 micron', '30 micron', '40 micron', '50 micron'])
plt.xlabel('Time (ns)')
plt.ylabel('Courant number')
plt.title('Simulated signal at $r=15,z=0.10$, Energy=$5$MeV')
# Out:
# Text(0.5, 1.0, 'Simulated signal at $r=15,z=0.10$, Energy=$5$MeV')

# %%
sim_time=6000
time_step_calc = 0.05
n_iter = sim_time/time_step_calc
step_time_out = 10 #out every step for now
time = np.linspace(start=0, stop= n_iter*time_step_calc - step_time_out*time_step_calc, num= (int) (sim_time/step_time_out))

# %%
print(len(time))
# Out:
# 600

# %%
grid_10m_r15_z0p10 = np.loadtxt('/Users/kevinhbhimani/Desktop/siggen_ccd/waveforms/5000.00_keV/grid_0.0100/self_repulsion_1/P42575A/q=0.00/signal_r=15.00_phi=0.00_z=0.10.txt')
grid_20m_r15_z0p10 = np.loadtxt('/Users/kevinhbhimani/Desktop/siggen_ccd/waveforms/5000.00_keV/grid_0.0200/self_repulsion_1/P42575A/q=0.00/signal_r=15.00_phi=0.00_z=0.10.txt')
grid_15m_r15_z0p10 = np.loadtxt('/Users/kevinhbhimani/Desktop/siggen_ccd/waveforms/5000.00_keV/grid_0.0150/self_repulsion_1/P42575A/q=0.00/signal_r=15.00_phi=0.00_z=0.10.txt')
grid_25m_r15_z0p10 = np.loadtxt('/Users/kevinhbhimani/Desktop/siggen_ccd/waveforms/5000.00_keV/grid_0.0250/self_repulsion_1/P42575A/q=0.00/signal_r=15.00_phi=0.00_z=0.10.txt')
grid_30m_r15_z0p10 = np.loadtxt('/Users/kevinhbhimani/Desktop/siggen_ccd/waveforms/5000.00_keV/grid_0.0300/self_repulsion_1/P42575A/q=0.00/signal_r=15.00_phi=0.00_z=0.10.txt')
grid_35m_r15_z0p10 = np.loadtxt('/Users/kevinhbhimani/Desktop/siggen_ccd/waveforms/5000.00_keV/grid_0.0350/self_repulsion_1/P42575A/q=0.00/signal_r=15.00_phi=0.00_z=0.10.txt')
grid_40m_r15_z0p10 = np.loadtxt('/Users/kevinhbhimani/Desktop/siggen_ccd/waveforms/5000.00_keV/grid_0.0400/self_repulsion_1/P42575A/q=0.00/signal_r=15.00_phi=0.00_z=0.10.txt')
# grid_40m_r15_z0p10 = np.loadtxt('/Users/kevinhbhimani/Desktop/siggen_sims/siggen_ccd_ll/waveforms_0p001ts/5000.00_keV/grid_0.0400/self_repulsion_1/P42575A/q=0.00/signal_r=15.00_phi=0.00_z=0.10.txt')

# %%
plt.plot(time, grid_10m_r15_z0p10,'-',markersize=2,color='tab:olive')
plt.plot(time, grid_15m_r15_z0p10,'-',markersize=2,color='tab:orange')
plt.plot(time, grid_20m_r15_z0p10,'-',markersize=2,color='tab:red')
plt.plot(time, grid_25m_r15_z0p10,'-',markersize=2,color='tab:blue')
plt.plot(time, grid_30m_r15_z0p10,'-',markersize=2,color='tab:green')
plt.plot(time, grid_35m_r15_z0p10,'-',markersize=2,color='tab:purple')
plt.plot(time, grid_40m_r15_z0p10,'-',markersize=2,color='tab:grey')
# plt.plot(time, grid_45m_r15_z0p10,'-',markersize=2,color='tab:pink')
# plt.plot(time, grid_50m_r15_z0p10,'-',markersize=2,color='tab:cyan')

plt.legend(['10 $\mu$ grid', '15 $\mu$ grid', '20 $\mu$ grid', '25 $\mu$ grid', '30 $\mu$ grid', '35 $\mu$ grid', '40 $\mu$ grid', '45 $\mu$ grid', '50 $\mu$ grid'])

plt.xlabel('Time (ns)')
plt.ylabel('Fraction of charge carriers collected')
plt.title('Signal collected at r=$15$, z=0.$10$, Time step =$0.001$ ns')
# Out:
# Text(0.5, 1.0, 'Signal collected at r=$15$, z=0.$10$, Time step =$0.001$ ns')
