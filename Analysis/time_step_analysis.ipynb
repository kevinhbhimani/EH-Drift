# %%
import os
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
from io import StringIO


from IPython.core.display import display, HTML
display(HTML("<style>.container { width:100% !important; }</style>")) #makes the notebook wider
plt.style.use('default')
# %matplotlib inline 
#makes plots fit the page

#plt.style.use('seaborn-deep')
# Out:
# <style>.container { width:100% !important; }</style>

# %%
n_iter = 4000
time_step_calc = 0.2
step_time_out = 10
time_old = np.linspace(start=0, stop= int (n_iter*time_step_calc - step_time_out*time_step_calc ), num= (int) (n_iter/step_time_out))

# %%
gpu_signal_g_0p02_t_0p20 = np.loadtxt('/Users/kevinhbhimani/Desktop/GPU_work/waveforms_all_ts/signal_r=15.00_phi=0.00_z=0.02_g_0p02_t_0p20.txt')
gpu_signal_g_0p02_t_0p15 = np.loadtxt('/Users/kevinhbhimani/Desktop/GPU_work/waveforms_all_ts/signal_r=15.00_phi=0.00_z=0.02_g_0p02_t_0p15.txt')
gpu_signal_g_0p02_t_0p10 = np.loadtxt('/Users/kevinhbhimani/Desktop/GPU_work/waveforms_all_ts/signal_r=15.00_phi=0.00_z=0.02_g_0p02_t_0p10.txt')
gpu_signal_g_0p02_t_0p05 = np.loadtxt('/Users/kevinhbhimani/Desktop/GPU_work/waveforms_all_ts/signal_r=15.00_phi=0.00_z=0.02_g_0p02_t_0p05.txt')
gpu_signal_g_0p02_t_0p25 = np.loadtxt('/Users/kevinhbhimani/Desktop/GPU_work/waveforms_all_ts/signal_r=15.00_phi=0.00_z=0.02_g_0p02_t_0p25.txt')
gpu_signal_g_0p02_t_0p30 = np.loadtxt('/Users/kevinhbhimani/Desktop/GPU_work/waveforms_all_ts/signal_r=15.00_phi=0.00_z=0.02_g_0p02_t_0p30.txt')

gpu_signal_g_0p01_t_0p05 = np.loadtxt('/Users/kevinhbhimani/Desktop/GPU_work/waveforms_all_ts/signal_r=15.00_phi=0.00_z=0.02_g_0p01_t_0p05.txt')
gpu_signal_g_0p01_t_0p10 = np.loadtxt('/Users/kevinhbhimani/Desktop/GPU_work/waveforms_all_ts/signal_r=15.00_phi=0.00_z=0.02_g_0p01_t_0p10.txt')
gpu_signal_g_0p01_t_0p15 = np.loadtxt('/Users/kevinhbhimani/Desktop/GPU_work/waveforms_all_ts/signal_r=15.00_phi=0.00_z=0.02_g_0p01_t_0p15.txt')
gpu_signal_g_0p01_t_0p20 = np.loadtxt('/Users/kevinhbhimani/Desktop/GPU_work/waveforms_all_ts/signal_r=15.00_phi=0.00_z=0.02_g_0p01_t_0p20.txt')
gpu_signal_g_0p01_t_0p25 = np.loadtxt('/Users/kevinhbhimani/Desktop/GPU_work/waveforms_all_ts/signal_r=15.00_phi=0.00_z=0.02_g_0p01_t_0p25.txt')
gpu_signal_g_0p01_t_0p30 = np.loadtxt('/Users/kevinhbhimani/Desktop/GPU_work/waveforms_all_ts/signal_r=15.00_phi=0.00_z=0.02_g_0p01_t_0p30.txt')

# %%
plt.plot(np.arange(0,800,0.05),gpu_signal_g_0p02_t_0p05,'-',markersize=2,color='tab:orange')
plt.plot(np.arange(0,800,0.10),gpu_signal_g_0p02_t_0p10,'-',markersize=2,color='tab:blue')
plt.plot(np.arange(0,800,0.15),gpu_signal_g_0p02_t_0p15,'-',markersize=2,color='tab:purple')
plt.plot(np.arange(0,800,0.20),gpu_signal_g_0p02_t_0p20,'-',markersize=2,color='tab:green')
plt.plot(np.arange(0,800,0.25),gpu_signal_g_0p02_t_0p25,'-',markersize=2,color='tab:grey')
plt.plot(np.arange(0,800,0.30),gpu_signal_g_0p02_t_0p30,'-',markersize=2,color='tab:cyan')

plt.legend(['t=0.05','t=0.10','t=0.15', 't=0.20','t=0.25', 't=0.30'])

plt.xlabel('Time (ns)')
plt.ylabel('Fraction of charge carriers collected')
plt.title('Simulated signal at $r=15,z=0.02$, grid=0.02, Energy=$5$MeV')
# Out:
# Text(0.5, 1.0, 'Simulated signal at $r=15,z=0.02$, grid=0.02, Energy=$5$MeV')

# %%
plt.plot(np.arange(0,800,0.05)[gpu_signal_g_0p02_t_0p05>0.6],gpu_signal_g_0p02_t_0p05[gpu_signal_g_0p02_t_0p05>0.6],'-',markersize=2,color='tab:orange')
plt.plot(np.arange(0,800,0.10)[gpu_signal_g_0p02_t_0p10>0.6],gpu_signal_g_0p02_t_0p10[gpu_signal_g_0p02_t_0p10>0.6],'-',markersize=2,color='tab:blue')
plt.plot(np.arange(0,800,0.15)[gpu_signal_g_0p02_t_0p15>0.6],gpu_signal_g_0p02_t_0p15[gpu_signal_g_0p02_t_0p15>0.6],'-',markersize=2,color='tab:purple')
plt.plot(np.arange(0,800,0.20)[gpu_signal_g_0p02_t_0p20>0.6],gpu_signal_g_0p02_t_0p20[gpu_signal_g_0p02_t_0p20>0.6],'-',markersize=2,color='tab:green')
plt.plot(np.arange(0,800,0.25)[gpu_signal_g_0p02_t_0p25>0.6],gpu_signal_g_0p02_t_0p25[gpu_signal_g_0p02_t_0p25>0.6],'-',markersize=2,color='tab:grey')
plt.plot(np.arange(0,800,0.30)[gpu_signal_g_0p02_t_0p30>0.6],gpu_signal_g_0p02_t_0p30[gpu_signal_g_0p02_t_0p30>0.6],'-',markersize=2,color='tab:cyan')

plt.legend(['t=0.05','t=0.10','t=0.15', 't=0.20','t=0.25', 't=0.30'])

plt.xlabel('Time (ns)')
plt.ylabel('Fraction of charge carriers collected')
plt.title('Simulated signal at $r=15,z=0.02$, grid=0.02, Energy=$5$MeV')
# Out:
# Text(0.5, 1.0, 'Simulated signal at $r=15,z=0.02$, grid=0.02, Energy=$5$MeV')

# %%
plt.plot(np.arange(0,800,0.05),gpu_signal_g_0p01_t_0p05,'-',markersize=2,color='tab:orange')
plt.plot(np.arange(0,800,0.10),gpu_signal_g_0p01_t_0p10,'-',markersize=2,color='tab:blue')
plt.plot(np.arange(0,800,0.15),gpu_signal_g_0p01_t_0p15,'-',markersize=2,color='tab:purple')
plt.plot(np.arange(0,800,0.20),gpu_signal_g_0p01_t_0p20,'-',markersize=2,color='tab:green')
plt.plot(np.arange(0,800,0.25),gpu_signal_g_0p01_t_0p25,'-',markersize=2,color='tab:grey')
plt.plot(np.arange(0,800,0.30),gpu_signal_g_0p01_t_0p30,'-',markersize=2,color='tab:cyan')

plt.legend(['t=0.05','t=0.10','t=0.15', 't=0.20','t=0.25', 't=0.30'])

plt.xlabel('Time (ns)')
plt.ylabel('Fraction of charge carriers collected')
plt.title('Simulated signal at $r=15,z=0.02$, grid=0.01, Energy=$5$MeV')
# Out:
# Text(0.5, 1.0, 'Simulated signal at $r=15,z=0.02$, grid=0.01, Energy=$5$MeV')

# %%
plt.plot(np.arange(0,800,0.05)[gpu_signal_g_0p01_t_0p05>0.6],gpu_signal_g_0p01_t_0p05[gpu_signal_g_0p01_t_0p05>0.6],'-',markersize=2,color='tab:orange')
plt.plot(np.arange(0,800,0.10)[gpu_signal_g_0p01_t_0p10>0.6],gpu_signal_g_0p01_t_0p10[gpu_signal_g_0p01_t_0p10>0.6],'-',markersize=2,color='tab:blue')
plt.plot(np.arange(0,800,0.15)[gpu_signal_g_0p01_t_0p15>0.6],gpu_signal_g_0p01_t_0p15[gpu_signal_g_0p01_t_0p15>0.6],'-',markersize=2,color='tab:purple')
plt.plot(np.arange(0,800,0.20)[gpu_signal_g_0p01_t_0p20>0.6],gpu_signal_g_0p01_t_0p20[gpu_signal_g_0p01_t_0p20>0.6],'-',markersize=2,color='tab:green')
plt.plot(np.arange(0,800,0.25)[gpu_signal_g_0p01_t_0p25>0.6],gpu_signal_g_0p01_t_0p25[gpu_signal_g_0p01_t_0p25>0.6],'-',markersize=2,color='tab:grey')
plt.plot(np.arange(0,800,0.30)[gpu_signal_g_0p01_t_0p30>0.6],gpu_signal_g_0p01_t_0p30[gpu_signal_g_0p01_t_0p30>0.6],'-',markersize=2,color='tab:cyan')

plt.legend(['t=0.05','t=0.10','t=0.15', 't=0.20','t=0.25', 't=0.30'])

plt.xlabel('Time (ns)')
plt.ylabel('Fraction of charge carriers collected')
plt.title('Simulated signal at $r=15,z=0.02$, grid=0.01, Energy=$5$MeV')
# Out:
# Text(0.5, 1.0, 'Simulated signal at $r=15,z=0.02$, grid=0.01, Energy=$5$MeV')

# %%
n=7 #number of files going through. Change accordingly
#color = plt.cm.hsv(np.linspace(0,1,n)) # input is 0 to 1 inclusive
color_array=np.linspace(0,1,n)
# Plot
cmap = plt.cm.Blues

plt.plot(np.arange(0,800,0.05)[gpu_signal_g_0p02_t_0p05>0.6],gpu_signal_g_0p02_t_0p05[gpu_signal_g_0p02_t_0p05>0.6],'-',markersize=2,color=cmap(color_array[0]))
plt.plot(np.arange(0,800,0.10)[gpu_signal_g_0p02_t_0p10>0.6],gpu_signal_g_0p02_t_0p10[gpu_signal_g_0p02_t_0p10>0.6],'-',markersize=2,color=cmap(color_array[1]))
plt.plot(np.arange(0,800,0.15)[gpu_signal_g_0p02_t_0p15>0.6],gpu_signal_g_0p02_t_0p15[gpu_signal_g_0p02_t_0p15>0.6],'-',markersize=2,color=cmap(color_array[2]))
plt.plot(np.arange(0,800,0.20)[gpu_signal_g_0p02_t_0p20>0.6],gpu_signal_g_0p02_t_0p20[gpu_signal_g_0p02_t_0p20>0.6],'-',markersize=2,color=cmap(color_array[3]))
plt.plot(np.arange(0,800,0.25)[gpu_signal_g_0p02_t_0p25>0.6],gpu_signal_g_0p02_t_0p25[gpu_signal_g_0p02_t_0p25>0.6],'-',markersize=2,color=cmap(color_array[4]))
plt.plot(np.arange(0,800,0.30)[gpu_signal_g_0p02_t_0p30>0.6],gpu_signal_g_0p02_t_0p30[gpu_signal_g_0p02_t_0p30>0.6],'-',markersize=2,color=cmap(color_array[5]))

cmap = plt.cm.Reds

plt.plot(np.arange(0,800,0.05)[gpu_signal_g_0p01_t_0p05>0.6],gpu_signal_g_0p01_t_0p05[gpu_signal_g_0p01_t_0p05>0.6],'-',markersize=2,color=cmap(color_array[0]))
plt.plot(np.arange(0,800,0.10)[gpu_signal_g_0p01_t_0p10>0.6],gpu_signal_g_0p01_t_0p10[gpu_signal_g_0p01_t_0p10>0.6],'-',markersize=2,color=cmap(color_array[1]))
plt.plot(np.arange(0,800,0.15)[gpu_signal_g_0p01_t_0p15>0.6],gpu_signal_g_0p01_t_0p15[gpu_signal_g_0p01_t_0p15>0.6],'-',markersize=2,color=cmap(color_array[2]))
plt.plot(np.arange(0,800,0.20)[gpu_signal_g_0p01_t_0p20>0.6],gpu_signal_g_0p01_t_0p20[gpu_signal_g_0p01_t_0p20>0.6],'-',markersize=2,color=cmap(color_array[3]))
plt.plot(np.arange(0,800,0.25)[gpu_signal_g_0p01_t_0p25>0.6],gpu_signal_g_0p01_t_0p25[gpu_signal_g_0p01_t_0p25>0.6],'-',markersize=2,color=cmap(color_array[4]))
plt.plot(np.arange(0,800,0.30)[gpu_signal_g_0p01_t_0p30>0.6],gpu_signal_g_0p01_t_0p30[gpu_signal_g_0p01_t_0p30>0.6],'-',markersize=2,color=cmap(color_array[5]))

plt.legend(['t=0.05, g=0.02','t=0.10, g=0.02','t=0.15, g=0.02', 't=0.20, g=0.02','t=0.25, g=0.02', 't=0.30, g=0.02', 't=0.05, g=0.01','t=0.10, g=0.01','t=0.15, g=0.01', 't=0.20, g=0.01','t=0.25, g=0.01', 't=0.30, g=0.01'])

plt.xlabel('Time (ns)')
plt.ylabel('Fraction of charge carriers collected')
plt.title('Simulated signal at $r=15,z=0.02$, Energy=$5$MeV')
# Out:
# Text(0.5, 1.0, 'Simulated signal at $r=15,z=0.02$, Energy=$5$MeV')
